# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, torch, pickle, csv
import numpy as np
import scipy as sp
sys.path.append('/lfs/1/danfu/metal')
sys.path.append('/lfs/1/danfu/sequential_ws')
from metal.metrics import metric_score
from torch.nn.functional import normalize
from DP.label_model import *
import pandas as pd
import matplotlib.pyplot as plt

from metal.analysis import lf_summary
from metal.label_model.baselines import MajorityLabelVoter
from metal.label_model import LabelModel

# %% [markdown]
# # Train Metal LabelModel

# %%
L_train_path = '/lfs/1/danfu/esper/app/data/shot_detection_weak_labels/L_train_100_windows_downsampled.npz'
L_dev_path = '/lfs/1/danfu/esper/app/data/shot_detection_weak_labels/L_val_windows_downsampled_same_val_test.npz'
Y_dev_path = '/lfs/1/danfu/esper/app/data/shot_detection_weak_labels/Y_val_windows_downsampled_same_val_test.npy'
L_test_path = '/lfs/1/danfu/esper/app/data/shot_detection_weak_labels/L_test_windows_downsampled_same_val_test.npz'
Y_test_path = '/lfs/1/danfu/esper/app/data/shot_detection_weak_labels/Y_test_windows_downsampled_same_val_test.npy'

stride = 1
L_train = sp.sparse.load_npz(L_train_path).todense()[::stride]
L_dev = sp.sparse.load_npz(L_dev_path).todense()
Y_dev = np.load(Y_dev_path)
L_test = sp.sparse.load_npz(L_test_path).todense()
Y_test = np.load(Y_test_path)

# %%
label_model = LabelModel(k=2, seed=123)
label_model.train_model(L_train, class_balance=(0.15, 0.85), n_epochs=500, log_train_every=50)
label_model.score((L_dev, Y_dev), metric=['accuracy','precision', 'recall', 'f1'])
# Out:
# Computing O...
# Estimating \mu...
# [50 epo]: TRAIN:[loss=0.059]
# [100 epo]: TRAIN:[loss=0.043]
# [150 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.039]
# [250 epo]: TRAIN:[loss=0.039]
# [300 epo]: TRAIN:[loss=0.038]
# [350 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [450 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# Finished Training
# Accuracy: 0.927
# Precision: 0.961
# Recall: 0.642
# F1: 0.770
#         y=1    y=2
#  l=1    221     9
#  l=2    123   1464
# [0.9273527793065492,
#  0.9608695652173913,
#  0.6424418604651163,
#  0.7700348432055749]

# %% [markdown]
# # Tune Metal LabelModel

# %%
from metal.tuners.random_tuner import RandomSearchTuner
#label_model_everything_windows_tuned = LabelModel(k=2, seed=123)
random_tuner = RandomSearchTuner(LabelModel, seed=123, validation_metric='f1')

# %%
search_space = {
    'seed' : [123],
    'n_epochs': list(range(500, 2000, 100)),
    'lr': {'range': [1e-5, .1], 'scale': 'log'},
    'l2': {'range': [1e-5, .1], 'scale': 'log'},
    'log_train_every': [100],
    'class_balance': [
        (i * .1, 1 - i * .1)
        for i in range(1, 10)
    ]
#     'Y_dev': [Y_test_windows]
}

# %%
best_random_model = random_tuner.search(search_space,
                                (L_dev, Y_dev),
                               train_args= [L_train],
                               train_kwargs = {
#                                    'Y_dev': Y_test_windows
#                                    'class_balance': (0.2, 0.8)
                               },
                               init_kwargs={
                                   'k': 2
                               }, verbose=True)
# Out:
# ============================================================
# [0] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 1.3078185548764493e-05, 'l2': 0.0001949089827110901}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.991]
# [200 epo]: TRAIN:[loss=1.900]
# [300 epo]: TRAIN:[loss=1.811]
# [400 epo]: TRAIN:[loss=1.723]
# [500 epo]: TRAIN:[loss=1.635]
# [600 epo]: TRAIN:[loss=1.550]
# [700 epo]: TRAIN:[loss=1.465]
# [800 epo]: TRAIN:[loss=1.383]
# [900 epo]: TRAIN:[loss=1.303]
# [1000 epo]: TRAIN:[loss=1.225]
# [1100 epo]: TRAIN:[loss=1.150]
# [1200 epo]: TRAIN:[loss=1.077]
# [1300 epo]: TRAIN:[loss=1.008]
# [1400 epo]: TRAIN:[loss=0.941]
# [1500 epo]: TRAIN:[loss=0.877]
# Finished Training
# ============================================================
# [1] Testing {'seed': 123, 'n_epochs': 500, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.06653717702911237, 'l2': 1.355578353389003e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.034]
# [300 epo]: TRAIN:[loss=0.034]
# [400 epo]: TRAIN:[loss=0.034]
# [500 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [2] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.001763408221933743, 'l2': 0.00045319628318724135}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.058]
# [200 epo]: TRAIN:[loss=0.052]
# [300 epo]: TRAIN:[loss=0.049]
# [400 epo]: TRAIN:[loss=0.046]
# [500 epo]: TRAIN:[loss=0.044]
# [600 epo]: TRAIN:[loss=0.042]
# [700 epo]: TRAIN:[loss=0.041]
# [800 epo]: TRAIN:[loss=0.040]
# Finished Training
# ============================================================
# [3] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 1.2449990694460814e-05, 'l2': 0.0035021576517552696}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.933]
# [200 epo]: TRAIN:[loss=1.767]
# [300 epo]: TRAIN:[loss=1.604]
# [400 epo]: TRAIN:[loss=1.444]
# [500 epo]: TRAIN:[loss=1.291]
# [600 epo]: TRAIN:[loss=1.144]
# [700 epo]: TRAIN:[loss=1.007]
# [800 epo]: TRAIN:[loss=0.880]
# [900 epo]: TRAIN:[loss=0.763]
# [1000 epo]: TRAIN:[loss=0.657]
# [1100 epo]: TRAIN:[loss=0.563]
# [1200 epo]: TRAIN:[loss=0.481]
# [1300 epo]: TRAIN:[loss=0.408]
# [1400 epo]: TRAIN:[loss=0.346]
# [1500 epo]: TRAIN:[loss=0.294]
# [1600 epo]: TRAIN:[loss=0.249]
# [1700 epo]: TRAIN:[loss=0.212]
# Finished Training
# ============================================================
# [4] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 4.5230810141142694e-05, 'l2': 0.07123967705408948}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=3.128]
# [200 epo]: TRAIN:[loss=2.779]
# [300 epo]: TRAIN:[loss=2.376]
# [400 epo]: TRAIN:[loss=1.933]
# [500 epo]: TRAIN:[loss=1.480]
# [600 epo]: TRAIN:[loss=1.059]
# [700 epo]: TRAIN:[loss=0.711]
# [800 epo]: TRAIN:[loss=0.457]
# [900 epo]: TRAIN:[loss=0.292]
# Finished Training
# ============================================================
# [5] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 1.807115927057947e-05, 'l2': 0.03012215427538453}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=3.293]
# [200 epo]: TRAIN:[loss=3.171]
# [300 epo]: TRAIN:[loss=3.040]
# [400 epo]: TRAIN:[loss=2.901]
# [500 epo]: TRAIN:[loss=2.752]
# [600 epo]: TRAIN:[loss=2.595]
# [700 epo]: TRAIN:[loss=2.430]
# [800 epo]: TRAIN:[loss=2.258]
# [900 epo]: TRAIN:[loss=2.080]
# [1000 epo]: TRAIN:[loss=1.899]
# [1100 epo]: TRAIN:[loss=1.716]
# [1200 epo]: TRAIN:[loss=1.535]
# [1300 epo]: TRAIN:[loss=1.358]
# [1400 epo]: TRAIN:[loss=1.188]
# [1500 epo]: TRAIN:[loss=1.029]
# [1600 epo]: TRAIN:[loss=0.882]
# [1700 epo]: TRAIN:[loss=0.749]
# Finished Training
# ============================================================
# [6] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 3.766489108813795e-05, 'l2': 0.004731984915225802}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.155]
# [200 epo]: TRAIN:[loss=1.919]
# [300 epo]: TRAIN:[loss=1.685]
# [400 epo]: TRAIN:[loss=1.458]
# [500 epo]: TRAIN:[loss=1.242]
# [600 epo]: TRAIN:[loss=1.041]
# [700 epo]: TRAIN:[loss=0.860]
# [800 epo]: TRAIN:[loss=0.701]
# [900 epo]: TRAIN:[loss=0.564]
# [1000 epo]: TRAIN:[loss=0.451]
# [1100 epo]: TRAIN:[loss=0.359]
# [1200 epo]: TRAIN:[loss=0.286]
# Finished Training
# ============================================================
# [7] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.009472312527528332, 'l2': 0.01990800345963798}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.044]
# [200 epo]: TRAIN:[loss=0.039]
# [300 epo]: TRAIN:[loss=0.039]
# [400 epo]: TRAIN:[loss=0.039]
# [500 epo]: TRAIN:[loss=0.039]
# [600 epo]: TRAIN:[loss=0.039]
# [700 epo]: TRAIN:[loss=0.039]
# [800 epo]: TRAIN:[loss=0.039]
# [900 epo]: TRAIN:[loss=0.039]
# [1000 epo]: TRAIN:[loss=0.039]
# [1100 epo]: TRAIN:[loss=0.039]
# [1200 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [8] Testing {'seed': 123, 'n_epochs': 1000, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.0032365969778500735, 'l2': 0.01077089348526747}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.055]
# [200 epo]: TRAIN:[loss=0.046]
# [300 epo]: TRAIN:[loss=0.042]
# [400 epo]: TRAIN:[loss=0.040]
# [500 epo]: TRAIN:[loss=0.039]
# [600 epo]: TRAIN:[loss=0.039]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.037]
# [1000 epo]: TRAIN:[loss=0.037]
# Finished Training
# ============================================================
# [9] Testing {'seed': 123, 'n_epochs': 1300, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.00035386233579753115, 'l2': 0.0001677471060485295}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.099]
# [200 epo]: TRAIN:[loss=0.066]
# [300 epo]: TRAIN:[loss=0.063]
# [400 epo]: TRAIN:[loss=0.061]
# [500 epo]: TRAIN:[loss=0.059]
# [600 epo]: TRAIN:[loss=0.057]
# [700 epo]: TRAIN:[loss=0.055]
# [800 epo]: TRAIN:[loss=0.054]
# [900 epo]: TRAIN:[loss=0.053]
# [1000 epo]: TRAIN:[loss=0.051]
# [1100 epo]: TRAIN:[loss=0.050]
# [1200 epo]: TRAIN:[loss=0.049]
# [1300 epo]: TRAIN:[loss=0.048]
# Finished Training
# ============================================================
# [10] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.045173995103473655, 'l2': 0.012297187901834967}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.039]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [11] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.00014614350111807501, 'l2': 0.022014017172621848}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.549]
# [200 epo]: TRAIN:[loss=0.776]
# [300 epo]: TRAIN:[loss=0.321]
# [400 epo]: TRAIN:[loss=0.141]
# [500 epo]: TRAIN:[loss=0.086]
# [600 epo]: TRAIN:[loss=0.069]
# Finished Training
# ============================================================
# [12] Testing {'seed': 123, 'n_epochs': 1100, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.000297819235319664, 'l2': 0.0013793745308172524}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.550]
# [200 epo]: TRAIN:[loss=0.107]
# [300 epo]: TRAIN:[loss=0.071]
# [400 epo]: TRAIN:[loss=0.065]
# [500 epo]: TRAIN:[loss=0.061]
# [600 epo]: TRAIN:[loss=0.058]
# [700 epo]: TRAIN:[loss=0.056]
# [800 epo]: TRAIN:[loss=0.054]
# [900 epo]: TRAIN:[loss=0.052]
# [1000 epo]: TRAIN:[loss=0.051]
# [1100 epo]: TRAIN:[loss=0.049]
# Finished Training
# ============================================================
# [13] Testing {'seed': 123, 'n_epochs': 1000, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.00022433511979938275, 'l2': 3.007910549117966e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.196]
# [200 epo]: TRAIN:[loss=0.054]
# [300 epo]: TRAIN:[loss=0.053]
# [400 epo]: TRAIN:[loss=0.052]
# [500 epo]: TRAIN:[loss=0.052]
# [600 epo]: TRAIN:[loss=0.052]
# [700 epo]: TRAIN:[loss=0.051]
# [800 epo]: TRAIN:[loss=0.051]
# [900 epo]: TRAIN:[loss=0.051]
# [1000 epo]: TRAIN:[loss=0.051]
# Finished Training
# ============================================================
# [14] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 4.647366012407341e-05, 'l2': 0.0022760418816132762}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.784]
# [200 epo]: TRAIN:[loss=1.477]
# [300 epo]: TRAIN:[loss=1.193]
# [400 epo]: TRAIN:[loss=0.941]
# [500 epo]: TRAIN:[loss=0.727]
# [600 epo]: TRAIN:[loss=0.553]
# [700 epo]: TRAIN:[loss=0.417]
# [800 epo]: TRAIN:[loss=0.314]
# [900 epo]: TRAIN:[loss=0.240]
# [1000 epo]: TRAIN:[loss=0.187]
# [1100 epo]: TRAIN:[loss=0.150]
# [1200 epo]: TRAIN:[loss=0.124]
# [1300 epo]: TRAIN:[loss=0.107]
# [1400 epo]: TRAIN:[loss=0.095]
# [1500 epo]: TRAIN:[loss=0.087]
# [1600 epo]: TRAIN:[loss=0.082]
# [1700 epo]: TRAIN:[loss=0.077]
# Finished Training
# ============================================================
# [15] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.000535462438541979, 'l2': 0.009235101607505701}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.195]
# [200 epo]: TRAIN:[loss=0.061]
# [300 epo]: TRAIN:[loss=0.056]
# [400 epo]: TRAIN:[loss=0.052]
# [500 epo]: TRAIN:[loss=0.050]
# [600 epo]: TRAIN:[loss=0.048]
# [700 epo]: TRAIN:[loss=0.046]
# [800 epo]: TRAIN:[loss=0.045]
# [900 epo]: TRAIN:[loss=0.043]
# [1000 epo]: TRAIN:[loss=0.043]
# [1100 epo]: TRAIN:[loss=0.042]
# [1200 epo]: TRAIN:[loss=0.042]
# [1300 epo]: TRAIN:[loss=0.041]
# [1400 epo]: TRAIN:[loss=0.041]
# [1500 epo]: TRAIN:[loss=0.041]
# Finished Training
# ============================================================
# [16] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.0006591167155301623, 'l2': 1.2090643524578612e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.067]
# [200 epo]: TRAIN:[loss=0.061]
# [300 epo]: TRAIN:[loss=0.058]
# [400 epo]: TRAIN:[loss=0.055]
# [500 epo]: TRAIN:[loss=0.052]
# [600 epo]: TRAIN:[loss=0.050]
# [700 epo]: TRAIN:[loss=0.048]
# [800 epo]: TRAIN:[loss=0.047]
# [900 epo]: TRAIN:[loss=0.045]
# [1000 epo]: TRAIN:[loss=0.044]
# [1100 epo]: TRAIN:[loss=0.043]
# [1200 epo]: TRAIN:[loss=0.043]
# [1300 epo]: TRAIN:[loss=0.042]
# [1400 epo]: TRAIN:[loss=0.041]
# [1500 epo]: TRAIN:[loss=0.041]
# [1600 epo]: TRAIN:[loss=0.041]
# Finished Training
# ============================================================
# [17] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.000629354735311117, 'l2': 0.008990422608929795}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.063]
# [200 epo]: TRAIN:[loss=0.060]
# [300 epo]: TRAIN:[loss=0.057]
# [400 epo]: TRAIN:[loss=0.055]
# [500 epo]: TRAIN:[loss=0.053]
# [600 epo]: TRAIN:[loss=0.052]
# [700 epo]: TRAIN:[loss=0.050]
# Finished Training
# ============================================================
# [18] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.007595308821436653, 'l2': 0.006984011818042419}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.043]
# [200 epo]: TRAIN:[loss=0.039]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [19] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.0006376685130857349, 'l2': 0.0005200380146473815}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.099]
# [200 epo]: TRAIN:[loss=0.063]
# [300 epo]: TRAIN:[loss=0.061]
# [400 epo]: TRAIN:[loss=0.059]
# [500 epo]: TRAIN:[loss=0.057]
# [600 epo]: TRAIN:[loss=0.055]
# [700 epo]: TRAIN:[loss=0.053]
# [800 epo]: TRAIN:[loss=0.052]
# [900 epo]: TRAIN:[loss=0.050]
# [1000 epo]: TRAIN:[loss=0.049]
# [1100 epo]: TRAIN:[loss=0.047]
# [1200 epo]: TRAIN:[loss=0.046]
# [1300 epo]: TRAIN:[loss=0.045]
# [1400 epo]: TRAIN:[loss=0.044]
# [1500 epo]: TRAIN:[loss=0.043]
# [1600 epo]: TRAIN:[loss=0.043]
# Finished Training
# ============================================================
# [20] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.0125110810645833, 'l2': 4.308336983667192e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.039]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# [1500 epo]: TRAIN:[loss=0.038]
# [1600 epo]: TRAIN:[loss=0.038]
# [1700 epo]: TRAIN:[loss=0.038]
# [1800 epo]: TRAIN:[loss=0.038]
# [1900 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [21] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.0001992623602949171, 'l2': 0.00116780510783321}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.654]
# [200 epo]: TRAIN:[loss=0.164]
# [300 epo]: TRAIN:[loss=0.088]
# [400 epo]: TRAIN:[loss=0.077]
# [500 epo]: TRAIN:[loss=0.072]
# [600 epo]: TRAIN:[loss=0.069]
# [700 epo]: TRAIN:[loss=0.066]
# [800 epo]: TRAIN:[loss=0.064]
# [900 epo]: TRAIN:[loss=0.062]
# [1000 epo]: TRAIN:[loss=0.060]
# [1100 epo]: TRAIN:[loss=0.059]
# [1200 epo]: TRAIN:[loss=0.057]
# [1300 epo]: TRAIN:[loss=0.056]
# [1400 epo]: TRAIN:[loss=0.055]
# [1500 epo]: TRAIN:[loss=0.053]
# [1600 epo]: TRAIN:[loss=0.052]
# [1700 epo]: TRAIN:[loss=0.051]
# [1800 epo]: TRAIN:[loss=0.050]
# Finished Training
# ============================================================
# [22] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.001683887906384242, 'l2': 0.00023674646742652}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.059]
# [200 epo]: TRAIN:[loss=0.052]
# [300 epo]: TRAIN:[loss=0.047]
# [400 epo]: TRAIN:[loss=0.044]
# [500 epo]: TRAIN:[loss=0.042]
# [600 epo]: TRAIN:[loss=0.041]
# [700 epo]: TRAIN:[loss=0.040]
# [800 epo]: TRAIN:[loss=0.039]
# [900 epo]: TRAIN:[loss=0.039]
# [1000 epo]: TRAIN:[loss=0.039]
# [1100 epo]: TRAIN:[loss=0.039]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [23] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 2.6248839405173808e-05, 'l2': 0.008040899823127697}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.512]
# [200 epo]: TRAIN:[loss=1.291]
# [300 epo]: TRAIN:[loss=1.086]
# [400 epo]: TRAIN:[loss=0.901]
# [500 epo]: TRAIN:[loss=0.738]
# [600 epo]: TRAIN:[loss=0.598]
# [700 epo]: TRAIN:[loss=0.482]
# [800 epo]: TRAIN:[loss=0.387]
# [900 epo]: TRAIN:[loss=0.311]
# [1000 epo]: TRAIN:[loss=0.251]
# [1100 epo]: TRAIN:[loss=0.206]
# [1200 epo]: TRAIN:[loss=0.171]
# [1300 epo]: TRAIN:[loss=0.145]
# [1400 epo]: TRAIN:[loss=0.126]
# [1500 epo]: TRAIN:[loss=0.112]
# [1600 epo]: TRAIN:[loss=0.102]
# Finished Training
# ============================================================
# [24] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 7.93628220714195e-05, 'l2': 0.0019087160011344462}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.586]
# [200 epo]: TRAIN:[loss=1.101]
# [300 epo]: TRAIN:[loss=0.714]
# [400 epo]: TRAIN:[loss=0.442]
# [500 epo]: TRAIN:[loss=0.273]
# [600 epo]: TRAIN:[loss=0.176]
# [700 epo]: TRAIN:[loss=0.125]
# [800 epo]: TRAIN:[loss=0.099]
# [900 epo]: TRAIN:[loss=0.085]
# [1000 epo]: TRAIN:[loss=0.077]
# [1100 epo]: TRAIN:[loss=0.073]
# [1200 epo]: TRAIN:[loss=0.070]
# [1300 epo]: TRAIN:[loss=0.067]
# [1400 epo]: TRAIN:[loss=0.066]
# Finished Training
# ============================================================
# [25] Testing {'seed': 123, 'n_epochs': 1000, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 2.351947071558437e-05, 'l2': 0.052391837247888956}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.235]
# [200 epo]: TRAIN:[loss=2.088]
# [300 epo]: TRAIN:[loss=1.941]
# [400 epo]: TRAIN:[loss=1.794]
# [500 epo]: TRAIN:[loss=1.649]
# [600 epo]: TRAIN:[loss=1.506]
# [700 epo]: TRAIN:[loss=1.368]
# [800 epo]: TRAIN:[loss=1.235]
# [900 epo]: TRAIN:[loss=1.109]
# [1000 epo]: TRAIN:[loss=0.989]
# Finished Training
# ============================================================
# [26] Testing {'seed': 123, 'n_epochs': 1100, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 9.396305111573652e-05, 'l2': 0.03515432024940864}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.014]
# [200 epo]: TRAIN:[loss=0.305]
# [300 epo]: TRAIN:[loss=0.097]
# [400 epo]: TRAIN:[loss=0.060]
# [500 epo]: TRAIN:[loss=0.055]
# [600 epo]: TRAIN:[loss=0.054]
# [700 epo]: TRAIN:[loss=0.053]
# [800 epo]: TRAIN:[loss=0.053]
# [900 epo]: TRAIN:[loss=0.053]
# [1000 epo]: TRAIN:[loss=0.053]
# [1100 epo]: TRAIN:[loss=0.053]
# Finished Training
# ============================================================
# [27] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.0001143389977239778, 'l2': 1.4862734648477203e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.177]
# [200 epo]: TRAIN:[loss=1.383]
# [300 epo]: TRAIN:[loss=0.695]
# [400 epo]: TRAIN:[loss=0.292]
# [500 epo]: TRAIN:[loss=0.134]
# [600 epo]: TRAIN:[loss=0.086]
# [700 epo]: TRAIN:[loss=0.072]
# [800 epo]: TRAIN:[loss=0.067]
# [900 epo]: TRAIN:[loss=0.065]
# [1000 epo]: TRAIN:[loss=0.064]
# [1100 epo]: TRAIN:[loss=0.064]
# [1200 epo]: TRAIN:[loss=0.063]
# Finished Training
# ============================================================
# [28] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.0010050540778820864, 'l2': 0.06675843844217566}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.079]
# [200 epo]: TRAIN:[loss=0.078]
# [300 epo]: TRAIN:[loss=0.078]
# [400 epo]: TRAIN:[loss=0.077]
# [500 epo]: TRAIN:[loss=0.076]
# [600 epo]: TRAIN:[loss=0.075]
# [700 epo]: TRAIN:[loss=0.074]
# [800 epo]: TRAIN:[loss=0.073]
# [900 epo]: TRAIN:[loss=0.072]
# [1000 epo]: TRAIN:[loss=0.072]
# [1100 epo]: TRAIN:[loss=0.071]
# [1200 epo]: TRAIN:[loss=0.070]
# [1300 epo]: TRAIN:[loss=0.069]
# [1400 epo]: TRAIN:[loss=0.068]
# [1500 epo]: TRAIN:[loss=0.067]
# [1600 epo]: TRAIN:[loss=0.066]
# Finished Training
# ============================================================
# [29] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.0010483928029179769, 'l2': 0.010776073388075276}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.062]
# [200 epo]: TRAIN:[loss=0.053]
# [300 epo]: TRAIN:[loss=0.048]
# [400 epo]: TRAIN:[loss=0.045]
# [500 epo]: TRAIN:[loss=0.043]
# [600 epo]: TRAIN:[loss=0.042]
# [700 epo]: TRAIN:[loss=0.041]
# [800 epo]: TRAIN:[loss=0.041]
# [900 epo]: TRAIN:[loss=0.040]
# [1000 epo]: TRAIN:[loss=0.040]
# [1100 epo]: TRAIN:[loss=0.040]
# [1200 epo]: TRAIN:[loss=0.040]
# [1300 epo]: TRAIN:[loss=0.040]
# [1400 epo]: TRAIN:[loss=0.040]
# Finished Training
# ============================================================
# [30] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.03666597107899235, 'l2': 1.1712272325603164e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# [1500 epo]: TRAIN:[loss=0.038]
# [1600 epo]: TRAIN:[loss=0.038]
# [1700 epo]: TRAIN:[loss=0.038]
# [1800 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [31] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.00011830393661064784, 'l2': 8.389036946505704e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.860]
# [200 epo]: TRAIN:[loss=0.265]
# [300 epo]: TRAIN:[loss=0.102]
# [400 epo]: TRAIN:[loss=0.073]
# [500 epo]: TRAIN:[loss=0.068]
# [600 epo]: TRAIN:[loss=0.066]
# [700 epo]: TRAIN:[loss=0.065]
# [800 epo]: TRAIN:[loss=0.064]
# [900 epo]: TRAIN:[loss=0.063]
# [1000 epo]: TRAIN:[loss=0.062]
# [1100 epo]: TRAIN:[loss=0.061]
# [1200 epo]: TRAIN:[loss=0.061]
# [1300 epo]: TRAIN:[loss=0.060]
# [1400 epo]: TRAIN:[loss=0.059]
# [1500 epo]: TRAIN:[loss=0.059]
# [1600 epo]: TRAIN:[loss=0.058]
# [1700 epo]: TRAIN:[loss=0.057]
# [1800 epo]: TRAIN:[loss=0.057]
# [1900 epo]: TRAIN:[loss=0.056]
# Finished Training
# ============================================================
# [32] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.002514244464083367, 'l2': 2.1625375621855228e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.055]
# [200 epo]: TRAIN:[loss=0.047]
# [300 epo]: TRAIN:[loss=0.043]
# [400 epo]: TRAIN:[loss=0.041]
# [500 epo]: TRAIN:[loss=0.040]
# [600 epo]: TRAIN:[loss=0.039]
# [700 epo]: TRAIN:[loss=0.039]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# [1500 epo]: TRAIN:[loss=0.038]
# [1600 epo]: TRAIN:[loss=0.038]
# [1700 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [33] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.001652489961770074, 'l2': 3.418774973304599e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.063]
# [200 epo]: TRAIN:[loss=0.053]
# [300 epo]: TRAIN:[loss=0.047]
# [400 epo]: TRAIN:[loss=0.043]
# [500 epo]: TRAIN:[loss=0.041]
# [600 epo]: TRAIN:[loss=0.040]
# [700 epo]: TRAIN:[loss=0.039]
# [800 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [34] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.036478696399219704, 'l2': 0.05518550995079234}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.042]
# [200 epo]: TRAIN:[loss=0.042]
# [300 epo]: TRAIN:[loss=0.042]
# [400 epo]: TRAIN:[loss=0.042]
# [500 epo]: TRAIN:[loss=0.042]
# [600 epo]: TRAIN:[loss=0.042]
# [700 epo]: TRAIN:[loss=0.042]
# [800 epo]: TRAIN:[loss=0.042]
# [900 epo]: TRAIN:[loss=0.042]
# Finished Training
# ============================================================
# [35] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 3.481640713879478e-05, 'l2': 0.04051086875161767}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.172]
# [200 epo]: TRAIN:[loss=1.953]
# [300 epo]: TRAIN:[loss=1.736]
# [400 epo]: TRAIN:[loss=1.524]
# [500 epo]: TRAIN:[loss=1.320]
# [600 epo]: TRAIN:[loss=1.129]
# [700 epo]: TRAIN:[loss=0.952]
# [800 epo]: TRAIN:[loss=0.794]
# [900 epo]: TRAIN:[loss=0.654]
# [1000 epo]: TRAIN:[loss=0.535]
# [1100 epo]: TRAIN:[loss=0.434]
# [1200 epo]: TRAIN:[loss=0.352]
# [1300 epo]: TRAIN:[loss=0.286]
# [1400 epo]: TRAIN:[loss=0.233]
# [1500 epo]: TRAIN:[loss=0.193]
# [1600 epo]: TRAIN:[loss=0.161]
# [1700 epo]: TRAIN:[loss=0.137]
# Finished Training
# ============================================================
# [36] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.0009314247278225025, 'l2': 0.0003921249644995564}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.062]
# [200 epo]: TRAIN:[loss=0.057]
# [300 epo]: TRAIN:[loss=0.054]
# [400 epo]: TRAIN:[loss=0.052]
# [500 epo]: TRAIN:[loss=0.050]
# [600 epo]: TRAIN:[loss=0.048]
# [700 epo]: TRAIN:[loss=0.047]
# [800 epo]: TRAIN:[loss=0.045]
# [900 epo]: TRAIN:[loss=0.044]
# [1000 epo]: TRAIN:[loss=0.043]
# [1100 epo]: TRAIN:[loss=0.043]
# [1200 epo]: TRAIN:[loss=0.042]
# [1300 epo]: TRAIN:[loss=0.041]
# [1400 epo]: TRAIN:[loss=0.041]
# [1500 epo]: TRAIN:[loss=0.040]
# [1600 epo]: TRAIN:[loss=0.040]
# [1700 epo]: TRAIN:[loss=0.040]
# [1800 epo]: TRAIN:[loss=0.040]
# [1900 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [37] Testing {'seed': 123, 'n_epochs': 500, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 1.296875713766964e-05, 'l2': 0.007162308158656614}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.617]
# [200 epo]: TRAIN:[loss=1.503]
# [300 epo]: TRAIN:[loss=1.393]
# [400 epo]: TRAIN:[loss=1.286]
# [500 epo]: TRAIN:[loss=1.182]
# Finished Training
# ============================================================
# [38] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.020554304952126283, 'l2': 0.029417565216287637}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.039]
# [300 epo]: TRAIN:[loss=0.039]
# [400 epo]: TRAIN:[loss=0.039]
# [500 epo]: TRAIN:[loss=0.039]
# [600 epo]: TRAIN:[loss=0.039]
# [700 epo]: TRAIN:[loss=0.039]
# [800 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [39] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.00023019027063898056, 'l2': 0.04549808156245954}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.460]
# [200 epo]: TRAIN:[loss=0.307]
# [300 epo]: TRAIN:[loss=0.087]
# [400 epo]: TRAIN:[loss=0.070]
# [500 epo]: TRAIN:[loss=0.067]
# [600 epo]: TRAIN:[loss=0.066]
# [700 epo]: TRAIN:[loss=0.065]
# [800 epo]: TRAIN:[loss=0.065]
# Finished Training
# ============================================================
# [40] Testing {'seed': 123, 'n_epochs': 1100, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.022980573511024897, 'l2': 0.050099792836123376}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.041]
# [200 epo]: TRAIN:[loss=0.040]
# [300 epo]: TRAIN:[loss=0.040]
# [400 epo]: TRAIN:[loss=0.040]
# [500 epo]: TRAIN:[loss=0.040]
# [600 epo]: TRAIN:[loss=0.040]
# [700 epo]: TRAIN:[loss=0.040]
# [800 epo]: TRAIN:[loss=0.040]
# [900 epo]: TRAIN:[loss=0.040]
# [1000 epo]: TRAIN:[loss=0.040]
# [1100 epo]: TRAIN:[loss=0.040]
# Finished Training
# ============================================================
# [41] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.0027479165901801036, 'l2': 1.056434414381598e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.053]
# [200 epo]: TRAIN:[loss=0.044]
# [300 epo]: TRAIN:[loss=0.041]
# [400 epo]: TRAIN:[loss=0.039]
# [500 epo]: TRAIN:[loss=0.039]
# [600 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [42] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.014967705039645784, 'l2': 0.002539739815884465}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.037]
# [300 epo]: TRAIN:[loss=0.035]
# [400 epo]: TRAIN:[loss=0.035]
# [500 epo]: TRAIN:[loss=0.034]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# [800 epo]: TRAIN:[loss=0.034]
# [900 epo]: TRAIN:[loss=0.034]
# [1000 epo]: TRAIN:[loss=0.034]
# [1100 epo]: TRAIN:[loss=0.034]
# [1200 epo]: TRAIN:[loss=0.034]
# [1300 epo]: TRAIN:[loss=0.034]
# [1400 epo]: TRAIN:[loss=0.034]
# [1500 epo]: TRAIN:[loss=0.034]
# [1600 epo]: TRAIN:[loss=0.034]
# [1700 epo]: TRAIN:[loss=0.034]
# [1800 epo]: TRAIN:[loss=0.034]
# [1900 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [43] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.07610360840733238, 'l2': 0.00023636231848814837}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# [1500 epo]: TRAIN:[loss=0.038]
# [1600 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [44] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.002180194891852838, 'l2': 0.005822085460025508}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.051]
# [200 epo]: TRAIN:[loss=0.048]
# [300 epo]: TRAIN:[loss=0.047]
# [400 epo]: TRAIN:[loss=0.045]
# [500 epo]: TRAIN:[loss=0.044]
# [600 epo]: TRAIN:[loss=0.043]
# [700 epo]: TRAIN:[loss=0.042]
# [800 epo]: TRAIN:[loss=0.041]
# [900 epo]: TRAIN:[loss=0.040]
# [1000 epo]: TRAIN:[loss=0.040]
# [1100 epo]: TRAIN:[loss=0.040]
# [1200 epo]: TRAIN:[loss=0.039]
# [1300 epo]: TRAIN:[loss=0.039]
# [1400 epo]: TRAIN:[loss=0.039]
# [1500 epo]: TRAIN:[loss=0.039]
# [1600 epo]: TRAIN:[loss=0.039]
# [1700 epo]: TRAIN:[loss=0.039]
# [1800 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [45] Testing {'seed': 123, 'n_epochs': 1300, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.00027706574909898093, 'l2': 0.0006967002409285529}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.899]
# [200 epo]: TRAIN:[loss=0.166]
# [300 epo]: TRAIN:[loss=0.072]
# [400 epo]: TRAIN:[loss=0.061]
# [500 epo]: TRAIN:[loss=0.057]
# [600 epo]: TRAIN:[loss=0.055]
# [700 epo]: TRAIN:[loss=0.053]
# [800 epo]: TRAIN:[loss=0.052]
# [900 epo]: TRAIN:[loss=0.050]
# [1000 epo]: TRAIN:[loss=0.049]
# [1100 epo]: TRAIN:[loss=0.048]
# [1200 epo]: TRAIN:[loss=0.047]
# [1300 epo]: TRAIN:[loss=0.046]
# Finished Training
# ============================================================
# [46] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.06772254330677809, 'l2': 0.026497437002342153}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.039]
# [200 epo]: TRAIN:[loss=0.039]
# [300 epo]: TRAIN:[loss=0.039]
# [400 epo]: TRAIN:[loss=0.039]
# [500 epo]: TRAIN:[loss=0.039]
# [600 epo]: TRAIN:[loss=0.039]
# [700 epo]: TRAIN:[loss=0.039]
# [800 epo]: TRAIN:[loss=0.039]
# [900 epo]: TRAIN:[loss=0.039]
# [1000 epo]: TRAIN:[loss=0.039]
# [1100 epo]: TRAIN:[loss=0.039]
# [1200 epo]: TRAIN:[loss=0.039]
# [1300 epo]: TRAIN:[loss=0.039]
# [1400 epo]: TRAIN:[loss=0.039]
# [1500 epo]: TRAIN:[loss=0.039]
# [1600 epo]: TRAIN:[loss=0.039]
# Finished Training
# ============================================================
# [47] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.00018282117652578764, 'l2': 7.351523448859335e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.726]
# [200 epo]: TRAIN:[loss=0.199]
# [300 epo]: TRAIN:[loss=0.096]
# [400 epo]: TRAIN:[loss=0.079]
# [500 epo]: TRAIN:[loss=0.074]
# [600 epo]: TRAIN:[loss=0.071]
# [700 epo]: TRAIN:[loss=0.068]
# [800 epo]: TRAIN:[loss=0.066]
# [900 epo]: TRAIN:[loss=0.064]
# [1000 epo]: TRAIN:[loss=0.062]
# [1100 epo]: TRAIN:[loss=0.060]
# [1200 epo]: TRAIN:[loss=0.059]
# [1300 epo]: TRAIN:[loss=0.057]
# [1400 epo]: TRAIN:[loss=0.056]
# [1500 epo]: TRAIN:[loss=0.055]
# Finished Training
# ============================================================
# [48] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.0006254424887643863, 'l2': 0.017613341842086273}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.075]
# [200 epo]: TRAIN:[loss=0.067]
# [300 epo]: TRAIN:[loss=0.061]
# [400 epo]: TRAIN:[loss=0.057]
# [500 epo]: TRAIN:[loss=0.054]
# [600 epo]: TRAIN:[loss=0.051]
# Finished Training
# ============================================================
# [49] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 5.886814070594576e-05, 'l2': 0.09733109337420415}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.359]
# [200 epo]: TRAIN:[loss=0.794]
# [300 epo]: TRAIN:[loss=0.416]
# [400 epo]: TRAIN:[loss=0.214]
# [500 epo]: TRAIN:[loss=0.124]
# [600 epo]: TRAIN:[loss=0.089]
# [700 epo]: TRAIN:[loss=0.076]
# [800 epo]: TRAIN:[loss=0.071]
# [900 epo]: TRAIN:[loss=0.069]
# [1000 epo]: TRAIN:[loss=0.068]
# [1100 epo]: TRAIN:[loss=0.067]
# [1200 epo]: TRAIN:[loss=0.067]
# [1300 epo]: TRAIN:[loss=0.066]
# [1400 epo]: TRAIN:[loss=0.066]
# Finished Training
# ============================================================
# [50] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.0003384526979502353, 'l2': 0.016763058310025163}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.841]
# [200 epo]: TRAIN:[loss=0.087]
# [300 epo]: TRAIN:[loss=0.065]
# [400 epo]: TRAIN:[loss=0.063]
# [500 epo]: TRAIN:[loss=0.062]
# [600 epo]: TRAIN:[loss=0.061]
# [700 epo]: TRAIN:[loss=0.060]
# [800 epo]: TRAIN:[loss=0.059]
# [900 epo]: TRAIN:[loss=0.058]
# [1000 epo]: TRAIN:[loss=0.057]
# [1100 epo]: TRAIN:[loss=0.056]
# [1200 epo]: TRAIN:[loss=0.055]
# [1300 epo]: TRAIN:[loss=0.055]
# [1400 epo]: TRAIN:[loss=0.054]
# [1500 epo]: TRAIN:[loss=0.053]
# [1600 epo]: TRAIN:[loss=0.052]
# [1700 epo]: TRAIN:[loss=0.051]
# Finished Training
# ============================================================
# [51] Testing {'seed': 123, 'n_epochs': 1000, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.02325422074253506, 'l2': 0.00031720521211805986}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [52] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.00011532326047594235, 'l2': 0.049855179112106573}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.815]
# [200 epo]: TRAIN:[loss=0.172]
# [300 epo]: TRAIN:[loss=0.066]
# [400 epo]: TRAIN:[loss=0.056]
# [500 epo]: TRAIN:[loss=0.054]
# [600 epo]: TRAIN:[loss=0.054]
# [700 epo]: TRAIN:[loss=0.054]
# [800 epo]: TRAIN:[loss=0.054]
# [900 epo]: TRAIN:[loss=0.053]
# Finished Training
# ============================================================
# [53] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.026627227372426857, 'l2': 0.00032034449995044635}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.035]
# [300 epo]: TRAIN:[loss=0.034]
# [400 epo]: TRAIN:[loss=0.034]
# [500 epo]: TRAIN:[loss=0.034]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [54] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 1.8907622638088542e-05, 'l2': 0.0001526145669951175}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.682]
# [200 epo]: TRAIN:[loss=1.491]
# [300 epo]: TRAIN:[loss=1.309]
# [400 epo]: TRAIN:[loss=1.137]
# [500 epo]: TRAIN:[loss=0.977]
# [600 epo]: TRAIN:[loss=0.832]
# [700 epo]: TRAIN:[loss=0.702]
# [800 epo]: TRAIN:[loss=0.588]
# Finished Training
# ============================================================
# [55] Testing {'seed': 123, 'n_epochs': 1000, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.04293888021723132, 'l2': 0.001026403963997391}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [56] Testing {'seed': 123, 'n_epochs': 1300, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.002641228576463227, 'l2': 1.6582358618505766e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.070]
# [200 epo]: TRAIN:[loss=0.068]
# [300 epo]: TRAIN:[loss=0.065]
# [400 epo]: TRAIN:[loss=0.063]
# [500 epo]: TRAIN:[loss=0.060]
# [600 epo]: TRAIN:[loss=0.057]
# [700 epo]: TRAIN:[loss=0.054]
# [800 epo]: TRAIN:[loss=0.051]
# [900 epo]: TRAIN:[loss=0.049]
# [1000 epo]: TRAIN:[loss=0.047]
# [1100 epo]: TRAIN:[loss=0.045]
# [1200 epo]: TRAIN:[loss=0.043]
# [1300 epo]: TRAIN:[loss=0.042]
# Finished Training
# ============================================================
# [57] Testing {'seed': 123, 'n_epochs': 1100, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.00033292040819101344, 'l2': 0.002207373260759409}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.114]
# [200 epo]: TRAIN:[loss=0.066]
# [300 epo]: TRAIN:[loss=0.063]
# [400 epo]: TRAIN:[loss=0.061]
# [500 epo]: TRAIN:[loss=0.059]
# [600 epo]: TRAIN:[loss=0.057]
# [700 epo]: TRAIN:[loss=0.056]
# [800 epo]: TRAIN:[loss=0.055]
# [900 epo]: TRAIN:[loss=0.053]
# [1000 epo]: TRAIN:[loss=0.052]
# [1100 epo]: TRAIN:[loss=0.051]
# Finished Training
# ============================================================
# [58] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.00015633508515112553, 'l2': 0.0007281023608557489}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.919]
# [200 epo]: TRAIN:[loss=0.879]
# [300 epo]: TRAIN:[loss=0.273]
# [400 epo]: TRAIN:[loss=0.104]
# [500 epo]: TRAIN:[loss=0.073]
# [600 epo]: TRAIN:[loss=0.067]
# [700 epo]: TRAIN:[loss=0.065]
# Finished Training
# ============================================================
# [59] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.011544649704774555, 'l2': 0.00668907674761432}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.057]
# [200 epo]: TRAIN:[loss=0.044]
# [300 epo]: TRAIN:[loss=0.039]
# [400 epo]: TRAIN:[loss=0.037]
# [500 epo]: TRAIN:[loss=0.036]
# [600 epo]: TRAIN:[loss=0.035]
# [700 epo]: TRAIN:[loss=0.035]
# [800 epo]: TRAIN:[loss=0.035]
# Finished Training
# ============================================================
# [60] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 9.347361690540736e-05, 'l2': 0.0006049111489404538}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.023]
# [200 epo]: TRAIN:[loss=0.487]
# [300 epo]: TRAIN:[loss=0.221]
# [400 epo]: TRAIN:[loss=0.121]
# [500 epo]: TRAIN:[loss=0.089]
# [600 epo]: TRAIN:[loss=0.079]
# [700 epo]: TRAIN:[loss=0.075]
# [800 epo]: TRAIN:[loss=0.073]
# [900 epo]: TRAIN:[loss=0.071]
# [1000 epo]: TRAIN:[loss=0.070]
# [1100 epo]: TRAIN:[loss=0.069]
# [1200 epo]: TRAIN:[loss=0.068]
# [1300 epo]: TRAIN:[loss=0.067]
# [1400 epo]: TRAIN:[loss=0.066]
# Finished Training
# ============================================================
# [61] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.023088657650435152, 'l2': 0.0017826497241461355}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [62] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.00023780090241769274, 'l2': 0.062395484535234844}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.279]
# [200 epo]: TRAIN:[loss=0.073]
# [300 epo]: TRAIN:[loss=0.067]
# [400 epo]: TRAIN:[loss=0.065]
# [500 epo]: TRAIN:[loss=0.063]
# [600 epo]: TRAIN:[loss=0.062]
# [700 epo]: TRAIN:[loss=0.061]
# [800 epo]: TRAIN:[loss=0.059]
# [900 epo]: TRAIN:[loss=0.058]
# [1000 epo]: TRAIN:[loss=0.057]
# [1100 epo]: TRAIN:[loss=0.056]
# [1200 epo]: TRAIN:[loss=0.055]
# [1300 epo]: TRAIN:[loss=0.054]
# [1400 epo]: TRAIN:[loss=0.054]
# [1500 epo]: TRAIN:[loss=0.053]
# Finished Training
# ============================================================
# [63] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.0006636586940866985, 'l2': 0.001994501091835785}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.053]
# [200 epo]: TRAIN:[loss=0.052]
# [300 epo]: TRAIN:[loss=0.051]
# [400 epo]: TRAIN:[loss=0.050]
# [500 epo]: TRAIN:[loss=0.049]
# [600 epo]: TRAIN:[loss=0.049]
# [700 epo]: TRAIN:[loss=0.048]
# [800 epo]: TRAIN:[loss=0.047]
# [900 epo]: TRAIN:[loss=0.047]
# [1000 epo]: TRAIN:[loss=0.046]
# [1100 epo]: TRAIN:[loss=0.046]
# [1200 epo]: TRAIN:[loss=0.045]
# [1300 epo]: TRAIN:[loss=0.045]
# [1400 epo]: TRAIN:[loss=0.044]
# [1500 epo]: TRAIN:[loss=0.044]
# Finished Training
# ============================================================
# [64] Testing {'seed': 123, 'n_epochs': 1300, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.04921591567631825, 'l2': 0.00022320980981290568}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.036]
# [200 epo]: TRAIN:[loss=0.034]
# [300 epo]: TRAIN:[loss=0.034]
# [400 epo]: TRAIN:[loss=0.034]
# [500 epo]: TRAIN:[loss=0.034]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# [800 epo]: TRAIN:[loss=0.034]
# [900 epo]: TRAIN:[loss=0.034]
# [1000 epo]: TRAIN:[loss=0.034]
# [1100 epo]: TRAIN:[loss=0.034]
# [1200 epo]: TRAIN:[loss=0.034]
# [1300 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [65] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 1.5670195498337426e-05, 'l2': 3.1142785202460466e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.800]
# [200 epo]: TRAIN:[loss=1.619]
# [300 epo]: TRAIN:[loss=1.442]
# [400 epo]: TRAIN:[loss=1.273]
# [500 epo]: TRAIN:[loss=1.113]
# [600 epo]: TRAIN:[loss=0.965]
# Finished Training
# ============================================================
# [66] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.000515798338529419, 'l2': 0.0009679052204809316}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.148]
# [200 epo]: TRAIN:[loss=0.068]
# [300 epo]: TRAIN:[loss=0.061]
# [400 epo]: TRAIN:[loss=0.056]
# [500 epo]: TRAIN:[loss=0.053]
# [600 epo]: TRAIN:[loss=0.050]
# [700 epo]: TRAIN:[loss=0.048]
# Finished Training
# ============================================================
# [67] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 3.369438749657511e-05, 'l2': 0.001381728555116413}
# ...
# Finished Training
# ============================================================
# [113] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.0006027332176939122, 'l2': 0.00025824057306356066}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.076]
# [200 epo]: TRAIN:[loss=0.067]
# [300 epo]: TRAIN:[loss=0.062]
# [400 epo]: TRAIN:[loss=0.058]
# [500 epo]: TRAIN:[loss=0.054]
# [600 epo]: TRAIN:[loss=0.051]
# [700 epo]: TRAIN:[loss=0.049]
# [800 epo]: TRAIN:[loss=0.047]
# [900 epo]: TRAIN:[loss=0.046]
# [1000 epo]: TRAIN:[loss=0.044]
# [1100 epo]: TRAIN:[loss=0.043]
# [1200 epo]: TRAIN:[loss=0.043]
# [1300 epo]: TRAIN:[loss=0.042]
# [1400 epo]: TRAIN:[loss=0.041]
# [1500 epo]: TRAIN:[loss=0.041]
# [1600 epo]: TRAIN:[loss=0.040]
# [1700 epo]: TRAIN:[loss=0.040]
# [1800 epo]: TRAIN:[loss=0.040]
# Finished Training
# ============================================================
# [114] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.0002825997233407023, 'l2': 0.00036504376634463934}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.369]
# [200 epo]: TRAIN:[loss=0.092]
# [300 epo]: TRAIN:[loss=0.075]
# [400 epo]: TRAIN:[loss=0.070]
# [500 epo]: TRAIN:[loss=0.066]
# [600 epo]: TRAIN:[loss=0.063]
# [700 epo]: TRAIN:[loss=0.061]
# [800 epo]: TRAIN:[loss=0.058]
# Finished Training
# ============================================================
# [115] Testing {'seed': 123, 'n_epochs': 1400, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 1.5450475137205943e-05, 'l2': 0.001081633755137166}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=3.308]
# [200 epo]: TRAIN:[loss=3.205]
# [300 epo]: TRAIN:[loss=3.096]
# [400 epo]: TRAIN:[loss=2.980]
# [500 epo]: TRAIN:[loss=2.858]
# [600 epo]: TRAIN:[loss=2.729]
# [700 epo]: TRAIN:[loss=2.595]
# [800 epo]: TRAIN:[loss=2.454]
# [900 epo]: TRAIN:[loss=2.308]
# [1000 epo]: TRAIN:[loss=2.157]
# [1100 epo]: TRAIN:[loss=2.003]
# [1200 epo]: TRAIN:[loss=1.847]
# [1300 epo]: TRAIN:[loss=1.691]
# [1400 epo]: TRAIN:[loss=1.536]
# Finished Training
# ============================================================
# [116] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.03473437800462462, 'l2': 2.395669886529758e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.036]
# [200 epo]: TRAIN:[loss=0.035]
# [300 epo]: TRAIN:[loss=0.034]
# [400 epo]: TRAIN:[loss=0.034]
# [500 epo]: TRAIN:[loss=0.034]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# [800 epo]: TRAIN:[loss=0.034]
# [900 epo]: TRAIN:[loss=0.034]
# [1000 epo]: TRAIN:[loss=0.034]
# [1100 epo]: TRAIN:[loss=0.034]
# [1200 epo]: TRAIN:[loss=0.034]
# [1300 epo]: TRAIN:[loss=0.034]
# [1400 epo]: TRAIN:[loss=0.034]
# [1500 epo]: TRAIN:[loss=0.034]
# [1600 epo]: TRAIN:[loss=0.034]
# [1700 epo]: TRAIN:[loss=0.034]
# [1800 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [117] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.004547163527731377, 'l2': 0.008801280001224977}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.068]
# [200 epo]: TRAIN:[loss=0.063]
# [300 epo]: TRAIN:[loss=0.058]
# [400 epo]: TRAIN:[loss=0.053]
# [500 epo]: TRAIN:[loss=0.048]
# [600 epo]: TRAIN:[loss=0.045]
# [700 epo]: TRAIN:[loss=0.043]
# [800 epo]: TRAIN:[loss=0.041]
# [900 epo]: TRAIN:[loss=0.040]
# [1000 epo]: TRAIN:[loss=0.039]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.037]
# [1300 epo]: TRAIN:[loss=0.037]
# [1400 epo]: TRAIN:[loss=0.036]
# [1500 epo]: TRAIN:[loss=0.036]
# [1600 epo]: TRAIN:[loss=0.036]
# [1700 epo]: TRAIN:[loss=0.035]
# [1800 epo]: TRAIN:[loss=0.035]
# Finished Training
# ============================================================
# [118] Testing {'seed': 123, 'n_epochs': 1800, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.013244677695937531, 'l2': 6.665065275283046e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.035]
# [400 epo]: TRAIN:[loss=0.035]
# [500 epo]: TRAIN:[loss=0.035]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# [800 epo]: TRAIN:[loss=0.034]
# [900 epo]: TRAIN:[loss=0.034]
# [1000 epo]: TRAIN:[loss=0.034]
# [1100 epo]: TRAIN:[loss=0.034]
# [1200 epo]: TRAIN:[loss=0.034]
# [1300 epo]: TRAIN:[loss=0.034]
# [1400 epo]: TRAIN:[loss=0.034]
# [1500 epo]: TRAIN:[loss=0.034]
# [1600 epo]: TRAIN:[loss=0.034]
# [1700 epo]: TRAIN:[loss=0.034]
# [1800 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [119] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.00034445607458292885, 'l2': 0.0004733243662319418}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.743]
# [200 epo]: TRAIN:[loss=0.076]
# [300 epo]: TRAIN:[loss=0.072]
# [400 epo]: TRAIN:[loss=0.071]
# [500 epo]: TRAIN:[loss=0.071]
# [600 epo]: TRAIN:[loss=0.071]
# Finished Training
# ============================================================
# [120] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.30000000000000004, 0.7), 'lr': 0.03201332732611739, 'l2': 3.649974994711279e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.038]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [121] Testing {'seed': 123, 'n_epochs': 500, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.02825488956983466, 'l2': 4.469551941277892e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.037]
# [200 epo]: TRAIN:[loss=0.035]
# [300 epo]: TRAIN:[loss=0.034]
# [400 epo]: TRAIN:[loss=0.034]
# [500 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [122] Testing {'seed': 123, 'n_epochs': 1700, 'log_train_every': 100, 'class_balance': (0.2, 0.8), 'lr': 0.01499978992282328, 'l2': 0.0002109116719953055}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.038]
# [300 epo]: TRAIN:[loss=0.038]
# [400 epo]: TRAIN:[loss=0.038]
# [500 epo]: TRAIN:[loss=0.038]
# [600 epo]: TRAIN:[loss=0.038]
# [700 epo]: TRAIN:[loss=0.038]
# [800 epo]: TRAIN:[loss=0.038]
# [900 epo]: TRAIN:[loss=0.038]
# [1000 epo]: TRAIN:[loss=0.038]
# [1100 epo]: TRAIN:[loss=0.038]
# [1200 epo]: TRAIN:[loss=0.038]
# [1300 epo]: TRAIN:[loss=0.038]
# [1400 epo]: TRAIN:[loss=0.038]
# [1500 epo]: TRAIN:[loss=0.038]
# [1600 epo]: TRAIN:[loss=0.038]
# [1700 epo]: TRAIN:[loss=0.038]
# Finished Training
# ============================================================
# [123] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 2.4708445682560398e-05, 'l2': 7.521280151245214e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.692]
# [200 epo]: TRAIN:[loss=2.539]
# [300 epo]: TRAIN:[loss=2.381]
# [400 epo]: TRAIN:[loss=2.217]
# [500 epo]: TRAIN:[loss=2.048]
# [600 epo]: TRAIN:[loss=1.875]
# [700 epo]: TRAIN:[loss=1.702]
# [800 epo]: TRAIN:[loss=1.529]
# [900 epo]: TRAIN:[loss=1.358]
# Finished Training
# ============================================================
# [124] Testing {'seed': 123, 'n_epochs': 900, 'log_train_every': 100, 'class_balance': (0.7000000000000001, 0.29999999999999993), 'lr': 0.0005258010009689193, 'l2': 6.35746763836813e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.207]
# [200 epo]: TRAIN:[loss=0.062]
# [300 epo]: TRAIN:[loss=0.056]
# [400 epo]: TRAIN:[loss=0.052]
# [500 epo]: TRAIN:[loss=0.050]
# [600 epo]: TRAIN:[loss=0.048]
# [700 epo]: TRAIN:[loss=0.046]
# [800 epo]: TRAIN:[loss=0.045]
# [900 epo]: TRAIN:[loss=0.044]
# Finished Training
# ============================================================
# [125] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.9, 0.09999999999999998), 'lr': 0.0004155880436736959, 'l2': 1.6806570464654242e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.366]
# [200 epo]: TRAIN:[loss=0.072]
# [300 epo]: TRAIN:[loss=0.071]
# [400 epo]: TRAIN:[loss=0.071]
# [500 epo]: TRAIN:[loss=0.071]
# [600 epo]: TRAIN:[loss=0.071]
# [700 epo]: TRAIN:[loss=0.070]
# [800 epo]: TRAIN:[loss=0.070]
# [900 epo]: TRAIN:[loss=0.070]
# [1000 epo]: TRAIN:[loss=0.069]
# [1100 epo]: TRAIN:[loss=0.069]
# [1200 epo]: TRAIN:[loss=0.069]
# Finished Training
# ============================================================
# [126] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 2.867781174231795e-05, 'l2': 0.006064390334301128}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.634]
# [200 epo]: TRAIN:[loss=1.419]
# [300 epo]: TRAIN:[loss=1.218]
# [400 epo]: TRAIN:[loss=1.032]
# [500 epo]: TRAIN:[loss=0.865]
# [600 epo]: TRAIN:[loss=0.718]
# [700 epo]: TRAIN:[loss=0.591]
# [800 epo]: TRAIN:[loss=0.485]
# [900 epo]: TRAIN:[loss=0.396]
# [1000 epo]: TRAIN:[loss=0.325]
# [1100 epo]: TRAIN:[loss=0.268]
# [1200 epo]: TRAIN:[loss=0.223]
# [1300 epo]: TRAIN:[loss=0.188]
# [1400 epo]: TRAIN:[loss=0.161]
# [1500 epo]: TRAIN:[loss=0.141]
# [1600 epo]: TRAIN:[loss=0.125]
# [1700 epo]: TRAIN:[loss=0.114]
# [1800 epo]: TRAIN:[loss=0.105]
# [1900 epo]: TRAIN:[loss=0.098]
# Finished Training
# ============================================================
# [127] Testing {'seed': 123, 'n_epochs': 1500, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 3.446029292983568e-05, 'l2': 1.461214253991115e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=2.638]
# [200 epo]: TRAIN:[loss=2.421]
# [300 epo]: TRAIN:[loss=2.193]
# [400 epo]: TRAIN:[loss=1.956]
# [500 epo]: TRAIN:[loss=1.714]
# [600 epo]: TRAIN:[loss=1.473]
# [700 epo]: TRAIN:[loss=1.240]
# [800 epo]: TRAIN:[loss=1.021]
# [900 epo]: TRAIN:[loss=0.823]
# [1000 epo]: TRAIN:[loss=0.651]
# [1100 epo]: TRAIN:[loss=0.507]
# [1200 epo]: TRAIN:[loss=0.391]
# [1300 epo]: TRAIN:[loss=0.302]
# [1400 epo]: TRAIN:[loss=0.234]
# [1500 epo]: TRAIN:[loss=0.185]
# Finished Training
# ============================================================
# [128] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 0.0005726607339007223, 'l2': 0.017704093384533857}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.053]
# [200 epo]: TRAIN:[loss=0.052]
# [300 epo]: TRAIN:[loss=0.051]
# [400 epo]: TRAIN:[loss=0.051]
# [500 epo]: TRAIN:[loss=0.050]
# [600 epo]: TRAIN:[loss=0.049]
# Finished Training
# ============================================================
# [129] Testing {'seed': 123, 'n_epochs': 800, 'log_train_every': 100, 'class_balance': (0.1, 0.9), 'lr': 6.689547486010831e-05, 'l2': 9.048292033649532e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.298]
# [200 epo]: TRAIN:[loss=0.617]
# [300 epo]: TRAIN:[loss=0.251]
# [400 epo]: TRAIN:[loss=0.111]
# [500 epo]: TRAIN:[loss=0.069]
# [600 epo]: TRAIN:[loss=0.058]
# [700 epo]: TRAIN:[loss=0.054]
# [800 epo]: TRAIN:[loss=0.053]
# Finished Training
# ============================================================
# [130] Testing {'seed': 123, 'n_epochs': 1900, 'log_train_every': 100, 'class_balance': (0.8, 0.19999999999999996), 'lr': 0.013775274647056508, 'l2': 0.00023218247063874441}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.040]
# [200 epo]: TRAIN:[loss=0.037]
# [300 epo]: TRAIN:[loss=0.035]
# [400 epo]: TRAIN:[loss=0.035]
# [500 epo]: TRAIN:[loss=0.035]
# [600 epo]: TRAIN:[loss=0.034]
# [700 epo]: TRAIN:[loss=0.034]
# [800 epo]: TRAIN:[loss=0.034]
# [900 epo]: TRAIN:[loss=0.034]
# [1000 epo]: TRAIN:[loss=0.034]
# [1100 epo]: TRAIN:[loss=0.034]
# [1200 epo]: TRAIN:[loss=0.034]
# [1300 epo]: TRAIN:[loss=0.034]
# [1400 epo]: TRAIN:[loss=0.034]
# [1500 epo]: TRAIN:[loss=0.034]
# [1600 epo]: TRAIN:[loss=0.034]
# [1700 epo]: TRAIN:[loss=0.034]
# [1800 epo]: TRAIN:[loss=0.034]
# [1900 epo]: TRAIN:[loss=0.034]
# Finished Training
# ============================================================
# [131] Testing {'seed': 123, 'n_epochs': 1600, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 3.732725697456444e-05, 'l2': 0.005024705718053732}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.841]
# [200 epo]: TRAIN:[loss=1.590]
# [300 epo]: TRAIN:[loss=1.352]
# [400 epo]: TRAIN:[loss=1.132]
# [500 epo]: TRAIN:[loss=0.933]
# [600 epo]: TRAIN:[loss=0.760]
# [700 epo]: TRAIN:[loss=0.612]
# [800 epo]: TRAIN:[loss=0.489]
# [900 epo]: TRAIN:[loss=0.389]
# [1000 epo]: TRAIN:[loss=0.311]
# [1100 epo]: TRAIN:[loss=0.250]
# [1200 epo]: TRAIN:[loss=0.204]
# [1300 epo]: TRAIN:[loss=0.169]
# [1400 epo]: TRAIN:[loss=0.143]
# [1500 epo]: TRAIN:[loss=0.124]
# [1600 epo]: TRAIN:[loss=0.109]
# Finished Training
# ============================================================
# [132] Testing {'seed': 123, 'n_epochs': 700, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 0.000146805653836623, 'l2': 0.0047491700872309625}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.903]
# [200 epo]: TRAIN:[loss=0.321]
# [300 epo]: TRAIN:[loss=0.134]
# [400 epo]: TRAIN:[loss=0.090]
# [500 epo]: TRAIN:[loss=0.079]
# [600 epo]: TRAIN:[loss=0.075]
# [700 epo]: TRAIN:[loss=0.072]
# Finished Training
# ============================================================
# [133] Testing {'seed': 123, 'n_epochs': 1200, 'log_train_every': 100, 'class_balance': (0.6000000000000001, 0.3999999999999999), 'lr': 0.00024111249964372958, 'l2': 8.233995697256033e-05}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=0.758]
# [200 epo]: TRAIN:[loss=0.173]
# [300 epo]: TRAIN:[loss=0.083]
# [400 epo]: TRAIN:[loss=0.069]
# [500 epo]: TRAIN:[loss=0.064]
# [600 epo]: TRAIN:[loss=0.061]
# [700 epo]: TRAIN:[loss=0.059]
# [800 epo]: TRAIN:[loss=0.057]
# [900 epo]: TRAIN:[loss=0.055]
# [1000 epo]: TRAIN:[loss=0.054]
# [1100 epo]: TRAIN:[loss=0.052]
# [1200 epo]: TRAIN:[loss=0.051]
# Finished Training
# ============================================================
# [134] Testing {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.5, 0.5), 'lr': 1.751862418094096e-05, 'l2': 0.0015873253521826287}
# ============================================================
# Computing O...
# Estimating \mu...
# [100 epo]: TRAIN:[loss=1.712]
# [200 epo]: TRAIN:[loss=1.577]
# [300 epo]: TRAIN:[loss=1.447]
# [400 epo]: TRAIN:[loss=1.321]
# [500 epo]: TRAIN:[loss=1.200]
# [600 epo]: TRAIN:[loss=1.086]
# Finished Training
# ============================================================
# [SUMMARY]
# Best model: [48]
# Best config: {'seed': 123, 'n_epochs': 600, 'log_train_every': 100, 'class_balance': (0.4, 0.6), 'lr': 0.0006254424887643863, 'l2': 0.017613341842086273}
# Best score: 0.8407460545193686
# ============================================================

# %%
best_random_model.score((L_dev, Y_dev), metric=['accuracy','precision', 'recall', 'f1'])
# Out:
# Accuracy: 0.939
# Precision: 0.830
# Recall: 0.852
# F1: 0.841
#         y=1    y=2
#  l=1    293    60
#  l=2    51    1413
# [0.9389102916895983, 0.830028328611898, 0.8517441860465116, 0.8407460545193686]

# %%
best_random_model.score((L_test, Y_test), metric=['accuracy','precision', 'recall', 'f1'])
# Out:
# Accuracy: 0.936
# Precision: 0.782
# Recall: 0.844
# F1: 0.812
#         y=1    y=2
#  l=1    255    71
#  l=2    47    1473
# [0.9360780065005417,
#  0.7822085889570553,
#  0.8443708609271523,
#  0.8121019108280254]

# %% [markdown]
# # Save/Load Best Model

# %%
torch.save(best_random_model, 'models/metal_labelmodel_downsampled_same_val_test.pth')

# %%
model = torch.load('models/metal_labelmodel_downsampled_same_val_test.pth')

# %% [markdown]
# # Make Predictions for Everything and Save to Disk

# %%
import numpy as np
from scipy.sparse import csr_matrix
import scipy.sparse as sparse
import pickle
import rekall
from rekall.video_interval_collection import VideoIntervalCollection
from rekall.interval_list import IntervalList
from rekall.temporal_predicates import *
from metal.label_model.baselines import MajorityLabelVoter

# %% [markdown]
# # Load Manually Annotated Data

# %%
with open('../../data/manually_annotated_shots.pkl', 'rb') as f:
    shots = VideoIntervalCollection(pickle.load(f))
with open('../../data/shot_detection_folds.pkl', 'rb') as f:
    shot_detection_folds = pickle.load(f)
clips = shots.dilate(1).coalesce().dilate(-1)
shot_boundaries = shots.map(
    lambda intrvl: (intrvl.start, intrvl.start, intrvl.payload)
).set_union(
    shots.map(lambda intrvl: (intrvl.end + 1, intrvl.end + 1, intrvl.payload))
).coalesce()
boundary_frames = {
    video_id: [
        intrvl.start
        for intrvl in shot_boundaries.get_intervallist(video_id).get_intervals()
    ]
    for video_id in shot_boundaries.get_allintervals()
}
video_ids = sorted(list(clips.get_allintervals().keys()))
frames_per_video = {
    video_id: sorted([
        f
        for interval in clips.get_intervallist(video_id).get_intervals()
        for f in range(interval.start, interval.end + 2)
    ])
    for video_id in video_ids
}
ground_truth = {
    video_id: [
        1 if f in boundary_frames[video_id] else 2
        for f in frames_per_video[video_id]
    ] 
    for video_id in video_ids
}
# Out:
# 100%|██████████| 28/28 [00:00<00:00, 4712.13it/s]
# 100%|██████████| 28/28 [00:00<00:00, 61583.91it/s]

# %% [markdown]
# # Load Label Matrix with All Frames in it

# %%
with open('../../data/shot_detection_weak_labels/all_labels.pkl', 'rb') as f:
    weak_labels_all_movies = pickle.load(f)

# %% [markdown]
# # Load Videos and Number of Frames Per Video

# %%
with open('../../data/frame_counts.pkl', 'rb') as f:
    frame_counts = pickle.load(f)
video_ids_all = sorted(list(frame_counts.keys()))
video_ids_train = sorted(list(set(video_ids_all).difference(set(video_ids))))

# %% [markdown]
# # Construct windows for each video

# %%
# First, construct windows of 16 frames for each video
windows = VideoIntervalCollection({
    video_id: [
        (f, f + 16, video_id)
        for f in range(0, frame_counts[video_id] - 16, 16)
    ]
    for video_id in video_ids_all
})

# %% [markdown]
# # Get weak labels for all windows

# %%
# Label windows with the weak labels in our labeling functions
def label_window(per_frame_weak_labels):
    if 1 in per_frame_weak_labels:
        return 1
    if len([l for l in per_frame_weak_labels if l == 2]) >= len(per_frame_weak_labels) / 2:
        return 2
    return 0

windows_with_weak_labels = windows.map(
    lambda window: (
        window.start,
        window.end,
        [
            label_window([
                lf[window.payload][f-1]
                for f in range(window.start, window.end)
            ])
            for lf in weak_labels_all_movies
        ]
    )
)

# %% [markdown]
# # L matrix

# %%
L_everything_windows = csr_matrix([
    intrvl.payload
    for video_id in sorted(list(video_ids_all))
    for intrvl in windows_with_weak_labels.get_intervallist(video_id).get_intervals()
]).todense()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1fb013569a51> in <module>
#       1 L_everything_windows = csr_matrix([
#       2     intrvl.payload
# ----> 3     for video_id in sorted(list(video_ids_all))
#       4     for intrvl in windows_with_weak_labels.get_intervallist(video_id).get_intervals()
#       5 ]).todense()
#
# /lfs/1/danfu/anaconda3/envs/metal/lib/python3.6/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      76             # must be dense
#      77             try:
# ---> 78                 arg1 = np.asarray(arg1)
#      79             except Exception:
#      80                 raise ValueError("unrecognized {}_matrix constructor usage"
#
# /lfs/1/danfu/anaconda3/envs/metal/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:

# %%
with open('../../data/shot_detection_weak_labels/L_everything_windows_downsampled.npy', 'wb') as f:
    np.save(f, L_everything_windows)

# %%
with open('../../data/shot_detection_weak_labels/L_everything_windows_downsampled.npy', 'rb') as f:
    L_everything_windows = np.load(f)

# %% [markdown]
# # Predict Everything

# %%
L_everything_windows.shape
# Out:
# (6175405, 5)

# %%
window_predictions_everything = model.predict_proba(L_everything_windows)

# %%
window_predictions_everything.shape
# Out:
# (6175405, 2)

# %%
fig, ax = plt.subplots()
ax.hist([
    pred[0] for pred in window_predictions_everything
], bins=20)
ax.set_xlim(0, 1)
plt.show()

# %%
window_nums = [
    (video_id, intrvl.start, intrvl.end)
    for video_id in sorted(list(video_ids_all))
    for intrvl in windows_with_weak_labels.get_intervallist(video_id).get_intervals()
]

# %%
predictions_to_save_windows = [
    (window_info, prediction)
    for window_info, prediction in zip(window_nums, window_predictions_everything)
]

# %%
preds_np_windows = np.array(predictions_to_save_windows)

# %%
preds_np_windows.shape
# Out:
# (6175405, 2)

# %%
# save predictions to disk
with open('../../data/shot_detection_weak_labels/noisy_labels_all_windows_downsampled_same_val_test.npy', 'wb') as f:
    np.save(f, preds_np_windows)
